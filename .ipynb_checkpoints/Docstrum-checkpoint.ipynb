# %%
#!/usr/bin/python
# find . -name '.DS_Store' -type f -delete
# Chulwoo Pack

import sys
import os
from page import Page

SHOW_STEPS = True    # change this to false if you just want to see the final output for each page.
SAVE_OUTPUT = True
SAVE_DOCSTRUM = True

inputFolder = os.path.join('images')
outputFolder = os.path.join('output')

    
inputPath = os.path.join(inputFolder, os.listdir(inputFolder)[0])
outputPath = os.path.join(outputFolder, os.listdir(inputFolder)[0])

page = Page(inputPath, SHOW_STEPS, SAVE_DOCSTRUM)
#page = Page(inputPath, SHOW_STEPS)
    
if SAVE_OUTPUT:
    page.save(outputPath)  # save a copy of what is displayed. Used for getting images for the paper.
    
page.show((800, 800))

# %%
# LINE EXTRACTION TESTING

import sys
import os
from page import Page

import cv2
import math
import numpy
import subprocess
import os

import colors
import geometry as g
from box import Box
import text
from dimension import Dimension
from stopwatch import Stopwatch
import numpy
import matplotlib.pyplot as plt
import ntpath


SHOW_STEPS = True    # change this to false if you just want to see the final output for each page.
SAVE_OUTPUT = True
SAVE_DOCSTRUM = False

inputFolder = os.path.join('images')
outputFolder = os.path.join('output')

    
inputPath = os.path.join(inputFolder, os.listdir(inputFolder)[0])
outputPath = os.path.join(outputFolder, os.listdir(inputFolder)[0])

page = Page(inputPath, SHOW_STEPS, SAVE_DOCSTRUM)


if True:
    page.save(outputPath)  # save a copy of what is displayed. Used for getting images for the paper.
    
page.show((800, 800))
# Out:
# 0.00	0.00	images/AC_2c_title_clean.jpg
# Total  2425  characters are found.
# 0.32	0.32	got characters
# 1.47	1.15	got words & tuples
# Total  355  words are found.
# 2.58	1.11	built Docstrum
# 2.58	0.00	finished analysing page
# average time: 2.58
#
# 355
# 355

# %%
for my_line in my_lines:
    my_line.group = None
    #print(my_line.group)

# %%
#from __future__ import division
#i=0
#j=5

#SHOW_DETAIL = True
SHOW_DETAIL = False

# Sorting lines
my_lines = page.lines
my_lines.sort(key=lambda line:((line.start.y+line.end.y)/2,(line.start.x+line.end.x)/2))
#my_lines[0].start.x = 2
#my_lines[0].start.y = 0
#my_lines[0].end.x = 6
#my_lines[0].end.y = 0

#my_lines[5].start.x = 1
#my_lines[5].start.y = 1
#my_lines[5].end.x = 5
#my_lines[5].end.y = 3

#my_lines[0].group = None
#my_lines[5].group = None

EPS = 3#1e-3
group_idx = 0
threshold_angle = 1.0
threshold_perpendist = 1.3 * 60.0
threshold_overlap    = 1.0
threshold_paralldist = 1.5 * 40.0

for idx_my_line, my_line in enumerate(my_lines):
    if(idx_my_line+1 == len(my_lines)-1):
        break
    i = idx_my_line
    for j in range(i+1,len(my_lines)-1):
    #for j in range(i+1,30):
        sameGroup = False
        ################################
        # CALCULATE GEOMETRIC FEATURES #
        ################################
        # Point setting
        x_O_i = my_lines[i].start.x
        #y_O_i = my_lines[i].start.y
        y_O_i = page.image.shape[0] - my_lines[i].start.y
        x_F_i = my_lines[i].end.x
        #y_F_i = my_lines[i].end.y
        y_F_i = page.image.shape[0] - my_lines[i].end.y 

        x_O_j = my_lines[j].start.x
        #y_O_j = my_lines[j].start.y
        y_O_j = page.image.shape[0] - my_lines[j].start.y
        x_F_j = my_lines[j].end.x
        #y_F_j = my_lines[j].end.y
        y_F_j = page.image.shape[0] - my_lines[j].end.y
        
        delta_x_i = abs(x_F_i - x_O_i)
        delta_y_i = abs(y_F_i - y_O_i)
        delta_x_j = abs(x_F_j - x_O_j)
        delta_y_j = abs(y_F_j - y_O_j)
        
        # ith or jth line is dot, so skip it
        if ((delta_x_i == 0 and delta_y_i == 0) or (delta_x_j == 0 and delta_y_j == 0)):
            continue
            
        if SHOW_DETAIL:
            print("\n****************************************************************")
            print(i, my_lines[i].points)
            print(j, my_lines[j].points)
            print("i:",x_O_i,y_O_i,"-",x_F_i,y_F_i)
            print("j:",x_O_j,y_O_j,"-",x_F_j,y_F_j)
            
        # Calculate angle
        theta_i_j = math.atan2(delta_y_j,delta_x_j-math.atan2(delta_y_i,delta_x_i))
        if SHOW_DETAIL:
            print("Angle:",theta_i_j)

        # Calculate overlap
        #if delta_x_j == 0:
        #    delta_x_j = 0.1
        #if delta_y_i == 0:
        #    delta_y_i = 0.1
        #if delta_y_j == 0:
        #    delta_y_j = 0.1
        #if delta_x_i == 0:
        #    delta_x_i = 0.1


        x_A_j = (x_O_i*delta_x_i*delta_x_j + x_O_j*delta_y_i*delta_y_j + delta_x_j*delta_y_i*(y_O_i-y_O_j))/(delta_y_i*delta_y_j + delta_x_i*delta_x_j + EPS)
        if (delta_x_j != 0):
            y_A_j = (delta_y_j/delta_x_j)*(x_A_j - x_O_j) + y_O_j
        else:
            x_A_j = y_O_j

        x_B_j = (x_F_i*delta_x_i*delta_x_j + x_F_j*delta_y_i*delta_y_j + delta_x_j*delta_y_i*(y_F_i-y_F_j))/(delta_y_i*delta_y_j + delta_x_i*delta_x_j + EPS)
        if (delta_x_j != 0):
            y_B_j = (delta_y_j/delta_x_j)*(x_A_j - x_F_j) + y_F_j
        else:
            x_B_j = y_F_j

        x_middle_candidates = [x_O_j, x_F_j, x_A_j, x_B_j]
        x_middle_candidates.sort()
        y_middle_candidates = [y_O_j, y_F_j, y_A_j, y_B_j]
        y_middle_candidates.sort()

        x_C_j = x_middle_candidates[-2]
        y_C_j = y_middle_candidates[-2]

        x_D_j = x_middle_candidates[-3]
        y_D_j = y_middle_candidates[-3]
        if SHOW_DETAIL:
            print("x_A_j,y_A_j",x_A_j,y_A_j)
            print("x_B_j,y_B_j",x_B_j,y_B_j)
            print("x_C_j,y_C_j",x_C_j,y_C_j)
            print("x_D_j,y_D_j",x_D_j,y_D_j)

        if ((x_O_j <= x_C_j <= x_F_j and y_O_j <= y_C_j <= y_F_j) or (x_O_i <= x_C_j <= x_F_i and y_O_i <= x_C_j <= y_F_i)) and ((x_O_j <= x_D_j <= x_F_j and y_O_j <= y_D_j <= y_F_j) or (x_O_i <= x_D_j <= x_F_i and y_O_i <= y_D_j <= y_F_i)):
            overlap = True
        else:
            overlap = False
        # Force to be true; no overlap is required in the default mode
        #overlap = True

        p_j = (math.sqrt(math.pow(y_D_j-y_C_j,2)+math.pow(x_D_j-x_C_j,2)))/2.0
        l_j = math.sqrt(math.pow(y_F_j-y_O_j,2)+math.pow(x_F_j-x_O_j,2))
        if (l_j == 0):
            l_j = 0.1
        if overlap:
            p_i_j = p_j/l_j
        else:
            p_i_j = -p_j/l_j
        
        if SHOW_DETAIL:
            print("Overlap?",overlap)
            print("p_j:",p_j)
            print("p_i_j:",p_i_j)

        # Calculate parallel_dist
        if overlap:
            d_i_j_a = p_j
        else:
            d_i_j_a = -p_j
        if SHOW_DETAIL:
            print("parallel_dist: ",d_i_j_a)

        # Calculate perpend_dist
        x_M_j = (x_C_j + x_D_j)/2.0
        y_M_j = (y_C_j + y_D_j)/2.0
        if SHOW_DETAIL:
            print("x_M_j,y_M_j",x_M_j,y_M_j)
            print("delta_x_i:",delta_x_i)
            print("delta_y_i:",delta_y_i)
            print("delta_x_j:",delta_x_j)
            print("delta_y_j:",delta_y_j)
            
        if delta_x_i != 0.0 and delta_x_i != 0.0:
            d_e_i_j = ((x_M_j - x_O_i) - (y_M_j - y_O_i)*delta_x_i/(delta_y_i + EPS))/((delta_x_i**2)/(delta_y_i**2 + EPS) + 1)**0.5
            #((x_M_j - x_O_i) - (y_M_j - y_O_i)*delta_x_i/(delta_y_i + EPS))/(math.pow(math.pow(delta_x_i,2)/math.pow(delta_y_i,2)+1,0.5) + EPS)
        elif delta_y_i == 0.0:
            d_e_i_j = y_M_j - y_O_i  
        elif delta_x_i == 0.0:
            d_e_i_j = x_M_j - x_O_i
        d_e_i_j = abs(d_e_i_j)
        
        if SHOW_DETAIL:
            print("perpend_dist: ",d_e_i_j)

        ######################
        # DECIDING GROUPNESS #
        #######################
        # 1. angle check
        if theta_i_j < threshold_angle:
            if SHOW_DETAIL: print("... Angle ok!")
        # 2. perpend_dist check
            if 0 < d_e_i_j < threshold_perpendist:
                if SHOW_DETAIL: print("... Perpendicular ok!")
        # 3.a. overlap check
        # 3.b. parallel_dist check
                if ((overlap and p_i_j < threshold_overlap)):
                    if SHOW_DETAIL: print("... Overlap & p_i_j ok!")
                    # Group!
                    sameGroup = True
                elif (abs(d_i_j_a) < threshold_paralldist):
                    if SHOW_DETAIL: print("... Parallel ok!")
                    # Group!
                    sameGroup = True
                    
        if SHOW_DETAIL:
            print("same group? ",sameGroup)
        if sameGroup:
            if SHOW_DETAIL:
                print("before group idx: ",group_idx)
                print("before i's group: ", my_lines[i].group)
                print("before j's group: ", my_lines[j].group)
            if (my_lines[i].group == None) and (my_lines[j].group == None):
                if SHOW_DETAIL:
                    print("... case 1")
                # Assign to a new block
                group_idx = group_idx + 1
                my_lines[i].group = group_idx
                my_lines[j].group = group_idx
            elif (my_lines[i].group == None):
                if SHOW_DETAIL: print("... case 2")
                # Unassigned text-line is assigned to the block of the other
                my_lines[i].group = my_lines[j].group
            elif (my_lines[j].group == None):
                if SHOW_DETAIL: print("... case 3")
                # Unassigned text-line is assigned to the block of the other
                my_lines[j].group = my_lines[i].group
            if SHOW_DETAIL: print("after group idx: ",group_idx)
            if SHOW_DETAIL: print("after i's group: ", my_lines[i].group)
            if SHOW_DETAIL: print("after j's group: ", my_lines[j].group)
            #else:
                # Block merge

print("Done!")
# Out:
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (6, [(x:2338, y:106), (x:2477, y:111)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2338, 1994, '-', 2477, 1989)
# ('Angle:', 0.03598711128013133)
# ('x_A_j,y_A_j', 2538, 1994)
# ('x_B_j,y_B_j', 2660, 1989)
# ('x_C_j,y_C_j', 2538, 1994)
# ('x_D_j,y_D_j', 2477, 1989)
# ('Overlap?', False)
# ('p_j:', 30.602287496198713)
# ('p_i_j:', -0.22001804386404866)
# ('parallel_dist: ', -30.602287496198713)
# ('x_M_j,y_M_j', 2507.5, 1991.5)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 139)
# ('delta_y_j:', 5)
# ('perpend_dist: ', 3.2476710624717806)
# ... Angle ok!
# ... Perpendicular ok!
# ... Parallel ok!
# ('same group? ', True)
# ('before group idx: ', 0)
# ("before i's group: ", None)
# ("before j's group: ", None)
# ... case 1
# ('after group idx: ', 1)
# ("after i's group: ", 1)
# ("after j's group: ", 1)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (7, [(x:2743, y:108), (x:2881, y:114)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2743, 1992, '-', 2881, 1986)
# ('Angle:', 0.043489089921440245)
# ('x_A_j,y_A_j', 2540, 1992)
# ('x_B_j,y_B_j', 2662, 1986)
# ('x_C_j,y_C_j', 2743, 1992)
# ('x_D_j,y_D_j', 2662, 1986)
# ('Overlap?', False)
# ('p_j:', 40.61095911204265)
# ('p_i_j:', -0.2940045565042879)
# ('parallel_dist: ', -40.61095911204265)
# ('x_M_j,y_M_j', 2702.5, 1989.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 138)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 29.15777405303818)
# ... Angle ok!
# ... Perpendicular ok!
# ... Parallel ok!
# ('same group? ', True)
# ('before group idx: ', 1)
# ("before i's group: ", 1)
# ("before j's group: ", None)
# ... case 3
# ('after group idx: ', 1)
# ("after i's group: ", 1)
# ("after j's group: ", 1)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (8, [(x:3813, y:112), (x:4061, y:112)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 3813, 1988, '-', 4061, 1988)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2540, 1988)
# ('x_B_j,y_B_j', 2661, 1988)
# ('x_C_j,y_C_j', 3813, 1988)
# ('x_D_j,y_D_j', 2661, 1988)
# ('Overlap?', False)
# ('p_j:', 576.0)
# ('p_i_j:', -2.3225806451612905)
# ('parallel_dist: ', -576.0)
# ('x_M_j,y_M_j', 3237.0, 1988.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 248)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 95.29216659791807)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (9, [(x:4115, y:112), (x:4227, y:112)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 4115, 1988, '-', 4227, 1988)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2539, 1988)
# ('x_B_j,y_B_j', 2661, 1988)
# ('x_C_j,y_C_j', 4115, 1988)
# ('x_D_j,y_D_j', 2661, 1988)
# ('Overlap?', False)
# ('p_j:', 727.0)
# ('p_i_j:', -6.491071428571429)
# ('parallel_dist: ', -727.0)
# ('x_M_j,y_M_j', 3388.0, 1988.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 112)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 113.73975269572016)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (10, [(x:509, y:110), (x:1001, y:116)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 509, 1990, '-', 1001, 1984)
# ('Angle:', 0.01219752567464642)
# ('x_A_j,y_A_j', 2537, 1990)
# ('x_B_j,y_B_j', 2659, 1984)
# ('x_C_j,y_C_j', 2537, 1990)
# ('x_D_j,y_D_j', 1001, 1984)
# ('Overlap?', False)
# ('p_j:', 768.0058593526484)
# ('p_i_j:', -1.5608714561430836)
# ('parallel_dist: ', -768.0058593526484)
# ('x_M_j,y_M_j', 1769.0, 1987.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 492)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 83.21775318070323)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (11, [(x:2980, y:114), (x:3453, y:116)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2980, 1986, '-', 3453, 1984)
# ('Angle:', 0.004229389682297807)
# ('x_A_j,y_A_j', 2540, 1986)
# ('x_B_j,y_B_j', 2662, 1984)
# ('x_C_j,y_C_j', 2980, 1986)
# ('x_D_j,y_D_j', 2662, 1984)
# ('Overlap?', False)
# ('p_j:', 159.00314462299164)
# ('p_i_j:', -0.3361558631109683)
# ('parallel_dist: ', -159.00314462299164)
# ('x_M_j,y_M_j', 2821.0, 1985.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 473)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 46.97415135499936)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (12, [(x:1150, y:116), (x:1227, y:116)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 1150, 1984, '-', 1227, 1984)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2540, 1984)
# ('x_B_j,y_B_j', 2661, 1984)
# ('x_C_j,y_C_j', 2540, 1984)
# ('x_D_j,y_D_j', 1227, 1984)
# ('Overlap?', False)
# ('p_j:', 656.5)
# ('p_i_j:', -8.525974025974026)
# ('parallel_dist: ', -656.5)
# ('x_M_j,y_M_j', 1883.5, 1984.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 77)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 66.72487819260203)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (13, [(x:3494, y:130), (x:3732, y:102)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 3494, 1970, '-', 3732, 1998)
# ('Angle:', 0.11716794157401621)
# ('x_A_j,y_A_j', 2555, 1970)
# ('x_B_j,y_B_j', 2675, 1998)
# ('x_C_j,y_C_j', 3494, 1998)
# ('x_D_j,y_D_j', 2675, 1970)
# ('Overlap?', False)
# ('p_j:', 409.7392463506516)
# ('p_i_j:', -1.7098015971762586)
# ('parallel_dist: ', -409.7392463506516)
# ('x_M_j,y_M_j', 3084.5, 1984.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 238)
# ('delta_y_j:', 28)
# ('perpend_dist: ', 80.00062447932054)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (14, [(x:1360, y:108), (x:1707, y:128)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 1360, 1992, '-', 1707, 1972)
# ('Angle:', 0.05759328796471242)
# ('x_A_j,y_A_j', 2531, 1992)
# ('x_B_j,y_B_j', 2656, 1972)
# ('x_C_j,y_C_j', 2531, 1992)
# ('x_D_j,y_D_j', 1707, 1972)
# ('Overlap?', False)
# ('p_j:', 412.1213413547034)
# ('p_i_j:', -1.1857017475423324)
# ('parallel_dist: ', -412.1213413547034)
# ('x_M_j,y_M_j', 2119.0, 1982.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 347)
# ('delta_y_j:', 20)
# ('perpend_dist: ', 36.28432497382265)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (15, [(x:2228, y:156), (x:2235, y:114)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2228, 1944, '-', 2235, 1986)
# ('Angle:', 1.4084602030193996)
# ('x_A_j,y_A_j', 2406, 3012)
# ('x_B_j,y_B_j', 2476, 3012)
# ('x_C_j,y_C_j', 2406, 3012)
# ('x_D_j,y_D_j', 2235, 1986)
# ('Overlap?', False)
# ('p_j:', 520.0761963404977)
# ('p_i_j:', -12.214285714285714)
# ('parallel_dist: ', -520.0761963404977)
# ('x_M_j,y_M_j', 2320.5, 2499.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 7)
# ('delta_y_j:', 42)
# ('perpend_dist: ', 443.2714672727941)
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (17, [(x:2313, y:182), (x:2514, y:193)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2313, 1918, '-', 2514, 1907)
# ('Angle:', 0.054704793168338546)
# ('x_A_j,y_A_j', 2547, 1918)
# ('x_B_j,y_B_j', 2670, 1907)
# ('x_C_j,y_C_j', 2547, 1918)
# ('x_D_j,y_D_j', 2514, 1907)
# ('Overlap?', False)
# ('p_j:', 17.392527130926087)
# ('p_i_j:', -0.08640069847463841)
# ('parallel_dist: ', -17.392527130926087)
# ('x_M_j,y_M_j', 2530.5, 1912.5)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 201)
# ('delta_y_j:', 11)
# ('perpend_dist: ', 72.00870666101223)
# ... Angle ok!
# ... Perpendicular ok!
# ... Parallel ok!
# ('same group? ', True)
# ('before group idx: ', 1)
# ("before i's group: ", 1)
# ("before j's group: ", None)
# ... case 3
# ('after group idx: ', 1)
# ("after i's group: ", 1)
# ("after j's group: ", 1)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (18, [(x:2606, y:197), (x:2687, y:191)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2606, 1903, '-', 2687, 1909)
# ('Angle:', 0.07404957252291625)
# ('x_A_j,y_A_j', 2550, 1903)
# ('x_B_j,y_B_j', 2670, 1909)
# ('x_C_j,y_C_j', 2670, 1909)
# ('x_D_j,y_D_j', 2606, 1903)
# ('Overlap?', True)
# ('p_j:', 32.14031735997639)
# ('p_i_j:', 0.39570990272974865)
# ('parallel_dist: ', 32.14031735997639)
# ('x_M_j,y_M_j', 2638.0, 1906.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 81)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 90.56828141614093)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (19, [(x:2784, y:195), (x:3595, y:194)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2784, 1905, '-', 3595, 1906)
# ('Angle:', 0.0012332295288763875)
# ('x_A_j,y_A_j', 2550, 1905)
# ('x_B_j,y_B_j', 2671, 1906)
# ('x_C_j,y_C_j', 2784, 1906)
# ('x_D_j,y_D_j', 2671, 1905)
# ('Overlap?', False)
# ('p_j:', 56.50221234606659)
# ('p_i_j:', -0.06966975264252916)
# ('parallel_dist: ', -56.50221234606659)
# ('x_M_j,y_M_j', 2727.5, 1905.5)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 811)
# ('delta_y_j:', 1)
# ('perpend_dist: ', 101.91985895424763)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (20, [(x:3698, y:185), (x:4243, y:248)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 3698, 1915, '-', 4243, 1852)
# ('Angle:', 0.11511093895670528)
# ('x_A_j,y_A_j', 2565, 1915)
# ('x_B_j,y_B_j', 2699, 1852)
# ('x_C_j,y_C_j', 3698, 1915)
# ('x_D_j,y_D_j', 2699, 1852)
# ('Overlap?', False)
# ('p_j:', 500.49225768237415)
# ('p_i_j:', -0.912259604352076)
# ('parallel_dist: ', -500.49225768237415)
# ('x_M_j,y_M_j', 3198.5, 1883.5)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 545)
# ('delta_y_j:', 63)
# ('perpend_dist: ', 177.82780704763195)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (21, [(x:2536, y:272), (x:2786, y:263)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2536, 1828, '-', 2786, 1837)
# ('Angle:', 0.036001920616762294)
# ('x_A_j,y_A_j', 2559, 1828)
# ('x_B_j,y_B_j', 2680, 1837)
# ('x_C_j,y_C_j', 2680, 1837)
# ('x_D_j,y_D_j', 2559, 1828)
# ('Overlap?', True)
# ('p_j:', 60.66712454039667)
# ('p_i_j:', 0.2425114016561006)
# ('parallel_dist: ', 60.66712454039667)
# ('x_M_j,y_M_j', 2619.5, 1832.5)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 250)
# ('delta_y_j:', 9)
# ('perpend_dist: ', 149.66775012350357)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (22, [(x:3502, y:270), (x:3537, y:274)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 3502, 1830, '-', 3537, 1826)
# ('Angle:', 0.11418449303455408)
# ('x_A_j,y_A_j', 2570, 1830)
# ('x_B_j,y_B_j', 2691, 1826)
# ('x_C_j,y_C_j', 3502, 1830)
# ('x_D_j,y_D_j', 2691, 1826)
# ('Overlap?', False)
# ('p_j:', 405.50493215249554)
# ('p_i_j:', -11.510925686194936)
# ('parallel_dist: ', -405.50493215249554)
# ('x_M_j,y_M_j', 3096.5, 1828.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 35)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 211.69928549541754)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (23, [(x:3625, y:272), (x:3743, y:273)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 3625, 1828, '-', 3743, 1827)
# ('Angle:', 0.008483097059651706)
# ('x_A_j,y_A_j', 2560, 1828)
# ('x_B_j,y_B_j', 2681, 1827)
# ('x_C_j,y_C_j', 3625, 1828)
# ('x_D_j,y_D_j', 2681, 1827)
# ('Overlap?', False)
# ('p_j:', 472.00026483043416)
# ('p_i_j:', -3.9998586150955435)
# ('parallel_dist: ', -472.00026483043416)
# ('x_M_j,y_M_j', 3153.0, 1827.5)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 118)
# ('delta_y_j:', 1)
# ('perpend_dist: ', 219.0192713697662)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (24, [(x:3815, y:272), (x:3921, y:272)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 3815, 1828, '-', 3921, 1828)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2559, 1828)
# ('x_B_j,y_B_j', 2680, 1828)
# ('x_C_j,y_C_j', 3815, 1828)
# ('x_D_j,y_D_j', 2680, 1828)
# ('Overlap?', False)
# ('p_j:', 567.5)
# ('p_i_j:', -5.35377358490566)
# ('parallel_dist: ', -567.5)
# ('x_M_j,y_M_j', 3247.5, 1828.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 106)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 230.14687159321963)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (25, [(x:2842, y:270), (x:3017, y:278)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2842, 1830, '-', 3017, 1822)
# ('Angle:', 0.04571413698616771)
# ('x_A_j,y_A_j', 2560, 1830)
# ('x_B_j,y_B_j', 2683, 1822)
# ('x_C_j,y_C_j', 2842, 1830)
# ('x_D_j,y_D_j', 2683, 1822)
# ('Overlap?', False)
# ('p_j:', 79.60056532462568)
# ('p_i_j:', -0.4543858342457344)
# ('parallel_dist: ', -79.60056532462568)
# ('x_M_j,y_M_j', 2762.5, 1826.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 175)
# ('delta_y_j:', 8)
# ('perpend_dist: ', 172.5643401532811)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (26, [(x:3079, y:277), (x:3410, y:275)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 3079, 1823, '-', 3410, 1825)
# ('Angle:', 0.006044438513057206)
# ('x_A_j,y_A_j', 2560, 1823)
# ('x_B_j,y_B_j', 2681, 1825)
# ('x_C_j,y_C_j', 3079, 1825)
# ('x_D_j,y_D_j', 2681, 1823)
# ('Overlap?', False)
# ('p_j:', 199.00251254695254)
# ('p_i_j:', -0.6012050752901608)
# ('parallel_dist: ', -199.00251254695254)
# ('x_M_j,y_M_j', 2880.0, 1824.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 331)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 188.58889893801648)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (27, [(x:2230, y:303), (x:2440, y:253)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 2230, 1797, '-', 2440, 1847)
# ('Angle:', 0.2338734581214617)
# ('x_A_j,y_A_j', 2554, 1797)
# ('x_B_j,y_B_j', 2671, 1847)
# ('x_C_j,y_C_j', 2554, 1847)
# ('x_D_j,y_D_j', 2440, 1797)
# ('Overlap?', False)
# ('p_j:', 62.24146527838174)
# ('p_i_j:', -0.2883280201615868)
# ('parallel_dist: ', -62.24146527838174)
# ('x_M_j,y_M_j', 2497.0, 1822.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 210)
# ('delta_y_j:', 50)
# ('perpend_dist: ', 143.4676508224211)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (28, [(x:1307, y:306), (x:1810, y:310)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 1307, 1794, '-', 1810, 1790)
# ('Angle:', 0.007954037539552027)
# ('x_A_j,y_A_j', 2562, 1794)
# ('x_B_j,y_B_j', 2684, 1790)
# ('x_C_j,y_C_j', 2562, 1794)
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 376.0053191113126)
# ('p_i_j:', -0.7475018501030745)
# ('parallel_dist: ', -376.0053191113126)
# ('x_M_j,y_M_j', 2186.0, 1792.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 130.51768972065273)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (5, [(x:2539, y:100), (x:2662, y:115)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 2539, 2000, '-', 2662, 1985)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.002304465565819173)
# ('x_A_j,y_A_j', 2563, 1791)
# ('x_B_j,y_B_j', 2685, 1789)
# ('x_C_j,y_C_j', 2563, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 629.0007949120574)
# ('p_i_j:', -0.7246533700530503)
# ('parallel_dist: ', -629.0007949120574)
# ('x_M_j,y_M_j', 1934.0, 1790.0)
# ('delta_x_i:', 123)
# ('delta_y_i:', 15)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 101.40063881573333)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (7, [(x:2743, y:108), (x:2881, y:114)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2743, 1992, '-', 2881, 1986)
# ('Angle:', 0.04346220516300619)
# ('x_A_j,y_A_j', 2338, 1992)
# ('x_B_j,y_B_j', 2477, 1986)
# ('x_C_j,y_C_j', 2743, 1992)
# ('x_D_j,y_D_j', 2477, 1986)
# ('Overlap?', False)
# ('p_j:', 133.0338302838793)
# ('p_i_j:', -0.9631033870628365)
# ('parallel_dist: ', -133.0338302838793)
# ('x_M_j,y_M_j', 2610.0, 1989.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 138)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 13.652248407402498)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (8, [(x:3813, y:112), (x:4061, y:112)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 3813, 1988, '-', 4061, 1988)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2338, 1988)
# ('x_B_j,y_B_j', 2476, 1988)
# ('x_C_j,y_C_j', 3813, 1988)
# ('x_D_j,y_D_j', 2476, 1988)
# ('Overlap?', False)
# ('p_j:', 668.5)
# ('p_i_j:', -2.6955645161290325)
# ('parallel_dist: ', -668.5)
# ('x_M_j,y_M_j', 3144.5, 1988.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 248)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 34.64656283397235)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (9, [(x:4115, y:112), (x:4227, y:112)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 4115, 1988, '-', 4227, 1988)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2337, 1988)
# ('x_B_j,y_B_j', 2476, 1988)
# ('x_C_j,y_C_j', 4115, 1988)
# ('x_D_j,y_D_j', 2476, 1988)
# ('Overlap?', False)
# ('p_j:', 819.5)
# ('p_i_j:', -7.316964285714286)
# ('parallel_dist: ', -819.5)
# ('x_M_j,y_M_j', 3295.5, 1988.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 112)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 40.39087355363177)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (10, [(x:509, y:110), (x:1001, y:116)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 509, 1990, '-', 1001, 1984)
# ('Angle:', 0.01219540860928756)
# ('x_A_j,y_A_j', 2337, 1990)
# ('x_B_j,y_B_j', 2476, 1984)
# ('x_C_j,y_C_j', 2337, 1990)
# ('x_D_j,y_D_j', 1001, 1984)
# ('Overlap?', False)
# ('p_j:', 668.0067364929788)
# ('p_i_j:', -1.357636318532847)
# ('parallel_dist: ', -668.0067364929788)
# ('x_M_j,y_M_j', 1669.0, 1987.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 492)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 20.823126358765425)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (11, [(x:2980, y:114), (x:3453, y:116)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2980, 1986, '-', 3453, 1984)
# ('Angle:', 0.004228626051647469)
# ('x_A_j,y_A_j', 2338, 1986)
# ('x_B_j,y_B_j', 2477, 1984)
# ('x_C_j,y_C_j', 2980, 1986)
# ('x_D_j,y_D_j', 2477, 1984)
# ('Overlap?', False)
# ('p_j:', 251.50198806371293)
# ('p_i_j:', -0.5317119235103287)
# ('parallel_dist: ', -251.50198806371293)
# ('x_M_j,y_M_j', 2728.5, 1985.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 473)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 20.80410546234271)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (12, [(x:1150, y:116), (x:1227, y:116)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 1150, 1984, '-', 1227, 1984)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2337, 1984)
# ('x_B_j,y_B_j', 2476, 1984)
# ('x_C_j,y_C_j', 2337, 1984)
# ('x_D_j,y_D_j', 1227, 1984)
# ('Overlap?', False)
# ('p_j:', 555.0)
# ('p_i_j:', -7.207792207792208)
# ('parallel_dist: ', -555.0)
# ('x_M_j,y_M_j', 1782.0, 1984.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 77)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 14.541475315164346)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (13, [(x:3494, y:130), (x:3732, y:102)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 3494, 1970, '-', 3732, 1998)
# ('Angle:', 0.11712627800369968)
# ('x_A_j,y_A_j', 2343, 1970)
# ('x_B_j,y_B_j', 2481, 1998)
# ('x_C_j,y_C_j', 3494, 1998)
# ('x_D_j,y_D_j', 2481, 1970)
# ('Overlap?', False)
# ('p_j:', 506.69344775712267)
# ('p_i_j:', -2.1143819489345717)
# ('parallel_dist: ', -506.69344775712267)
# ('x_M_j,y_M_j', 2987.5, 1984.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 238)
# ('delta_y_j:', 28)
# ('perpend_dist: ', 31.31790595999751)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (14, [(x:1360, y:108), (x:1707, y:128)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 1360, 1992, '-', 1707, 1972)
# ('Angle:', 0.057579144170846204)
# ('x_A_j,y_A_j', 2335, 1992)
# ('x_B_j,y_B_j', 2475, 1972)
# ('x_C_j,y_C_j', 2335, 1992)
# ('x_D_j,y_D_j', 1707, 1972)
# ('Overlap?', False)
# ('p_j:', 314.1591953134589)
# ('p_i_j:', -0.9038578435787911)
# ('parallel_dist: ', -314.1591953134589)
# ('x_M_j,y_M_j', 2021.0, 1982.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 347)
# ('delta_y_j:', 20)
# ('perpend_dist: ', 4.127534523728794)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (15, [(x:2228, y:156), (x:2235, y:114)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2228, 1944, '-', 2235, 1986)
# ('Angle:', 1.4064807158880823)
# ('x_A_j,y_A_j', 2314, 2460)
# ('x_B_j,y_B_j', 2427, 2460)
# ('x_C_j,y_C_j', 2314, 2460)
# ('x_D_j,y_D_j', 2235, 1986)
# ('Overlap?', False)
# ('p_j:', 240.26911994677968)
# ('p_i_j:', -5.642857142857143)
# ('parallel_dist: ', -240.26911994677968)
# ('x_M_j,y_M_j', 2274.5, 2223.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 7)
# ('delta_y_j:', 42)
# ('perpend_dist: ', 153.77919235353164)
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (17, [(x:2313, y:182), (x:2514, y:193)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2313, 1918, '-', 2514, 1907)
# ('Angle:', 0.05468159360946255)
# ('x_A_j,y_A_j', 2340, 1918)
# ('x_B_j,y_B_j', 2479, 1907)
# ('x_C_j,y_C_j', 2479, 1918)
# ('x_D_j,y_D_j', 2340, 1907)
# ('Overlap?', False)
# ('p_j:', 69.71728623519421)
# ('p_i_j:', -0.3463339272742212)
# ('parallel_dist: ', -69.71728623519421)
# ('x_M_j,y_M_j', 2409.5, 1912.5)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 201)
# ('delta_y_j:', 11)
# ('perpend_dist: ', 56.58954446962502)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (18, [(x:2606, y:197), (x:2687, y:191)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2606, 1903, '-', 2687, 1909)
# ('Angle:', 0.07397175398434815)
# ('x_A_j,y_A_j', 2341, 1903)
# ('x_B_j,y_B_j', 2479, 1909)
# ('x_C_j,y_C_j', 2606, 1909)
# ('x_D_j,y_D_j', 2479, 1903)
# ('Overlap?', False)
# ('p_j:', 63.57082664241515)
# ('p_i_j:', -0.7826806856128159)
# ('parallel_dist: ', -63.57082664241515)
# ('x_M_j,y_M_j', 2542.5, 1906.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 81)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 65.94544789754714)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (19, [(x:2784, y:195), (x:3595, y:194)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2784, 1905, '-', 3595, 1906)
# ('Angle:', 0.0012330996672525055)
# ('x_A_j,y_A_j', 2341, 1905)
# ('x_B_j,y_B_j', 2479, 1906)
# ('x_C_j,y_C_j', 2784, 1906)
# ('x_D_j,y_D_j', 2479, 1905)
# ('Overlap?', False)
# ('p_j:', 152.50081966992832)
# ('p_i_j:', -0.18804032520200054)
# ('parallel_dist: ', -152.50081966992832)
# ('x_M_j,y_M_j', 2631.5, 1905.5)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 811)
# ('delta_y_j:', 1)
# ('perpend_dist: ', 69.66165553613476)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (20, [(x:3698, y:185), (x:4243, y:248)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 3698, 1915, '-', 4243, 1852)
# ('Angle:', 0.11509305986808605)
# ('x_A_j,y_A_j', 2346, 1915)
# ('x_B_j,y_B_j', 2489, 1852)
# ('x_C_j,y_C_j', 3698, 1915)
# ('x_D_j,y_D_j', 2489, 1852)
# ('Overlap?', False)
# ('p_j:', 605.3201632194322)
# ('p_i_j:', -1.103332017885759)
# ('parallel_dist: ', -605.3201632194322)
# ('x_M_j,y_M_j', 3093.5, 1883.5)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 545)
# ('delta_y_j:', 63)
# ('perpend_dist: ', 101.77843914588622)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (21, [(x:2536, y:272), (x:2786, y:263)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2536, 1828, '-', 2786, 1837)
# ('Angle:', 0.035989631747103575)
# ('x_A_j,y_A_j', 2344, 1828)
# ('x_B_j,y_B_j', 2482, 1837)
# ('x_C_j,y_C_j', 2536, 1837)
# ('x_D_j,y_D_j', 2482, 1828)
# ('Overlap?', False)
# ('p_j:', 27.37243138634199)
# ('p_i_j:', -0.10941884509157972)
# ('parallel_dist: ', -27.37243138634199)
# ('x_M_j,y_M_j', 2509.0, 1832.5)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 250)
# ('delta_y_j:', 9)
# ('perpend_dist: ', 113.25279491288805)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (22, [(x:3502, y:270), (x:3537, y:274)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 3502, 1830, '-', 3537, 1826)
# ('Angle:', 0.11390801751753292)
# ('x_A_j,y_A_j', 2347, 1830)
# ('x_B_j,y_B_j', 2485, 1826)
# ('x_C_j,y_C_j', 3502, 1830)
# ('x_D_j,y_D_j', 2485, 1826)
# ('Overlap?', False)
# ('p_j:', 508.50393312146565)
# ('p_i_j:', -14.434722049441806)
# ('parallel_dist: ', -508.50393312146565)
# ('x_M_j,y_M_j', 2993.5, 1828.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 35)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 134.65843622459906)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (23, [(x:3625, y:272), (x:3743, y:273)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 3625, 1828, '-', 3743, 1827)
# ('Angle:', 0.008476956288351014)
# ('x_A_j,y_A_j', 2343, 1828)
# ('x_B_j,y_B_j', 2482, 1827)
# ('x_C_j,y_C_j', 3625, 1828)
# ('x_D_j,y_D_j', 2482, 1827)
# ('Overlap?', False)
# ('p_j:', 571.5002187226178)
# ('p_i_j:', -4.843048285593369)
# ('parallel_dist: ', -571.5002187226178)
# ('x_M_j,y_M_j', 3053.5, 1827.5)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 118)
# ('delta_y_j:', 1)
# ('perpend_dist: ', 137.27143187066932)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (24, [(x:3815, y:272), (x:3921, y:272)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 3815, 1828, '-', 3921, 1828)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2343, 1828)
# ('x_B_j,y_B_j', 2482, 1828)
# ('x_C_j,y_C_j', 3815, 1828)
# ('x_D_j,y_D_j', 2482, 1828)
# ('Overlap?', False)
# ('p_j:', 666.5)
# ('p_i_j:', -6.287735849056604)
# ('parallel_dist: ', -666.5)
# ('x_M_j,y_M_j', 3148.5, 1828.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 106)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 140.5549141156402)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (25, [(x:2842, y:270), (x:3017, y:278)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2842, 1830, '-', 3017, 1822)
# ('Angle:', 0.045691855924004945)
# ('x_A_j,y_A_j', 2344, 1830)
# ('x_B_j,y_B_j', 2483, 1822)
# ('x_C_j,y_C_j', 2842, 1830)
# ('x_D_j,y_D_j', 2483, 1822)
# ('Overlap?', False)
# ('p_j:', 179.5445627135503)
# ('p_i_j:', -1.024898574277378)
# ('parallel_dist: ', -179.5445627135503)
# ('x_M_j,y_M_j', 2662.5, 1826.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 175)
# ('delta_y_j:', 8)
# ('perpend_dist: ', 123.38855509414142)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (26, [(x:3079, y:277), (x:3410, y:275)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 3079, 1823, '-', 3410, 1825)
# ('Angle:', 0.006042878947881564)
# ('x_A_j,y_A_j', 2344, 1823)
# ('x_B_j,y_B_j', 2482, 1825)
# ('x_C_j,y_C_j', 3079, 1825)
# ('x_D_j,y_D_j', 2482, 1823)
# ('Overlap?', False)
# ('p_j:', 298.5016750371763)
# ('p_i_j:', -0.9018012874215486)
# ('parallel_dist: ', -298.5016750371763)
# ('x_M_j,y_M_j', 2780.5, 1824.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 331)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 129.19943895128034)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (27, [(x:2230, y:303), (x:2440, y:253)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 2230, 1797, '-', 2440, 1847)
# ('Angle:', 0.23378176622000865)
# ('x_A_j,y_A_j', 2343, 1797)
# ('x_B_j,y_B_j', 2481, 1847)
# ('x_C_j,y_C_j', 2440, 1847)
# ('x_D_j,y_D_j', 2343, 1797)
# ('Overlap?', True)
# ('p_j:', 54.56418239101544)
# ('p_i_j:', 0.2527636939485985)
# ('parallel_dist: ', 54.56418239101544)
# ('x_M_j,y_M_j', 2391.5, 1822.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 210)
# ('delta_y_j:', 50)
# ('perpend_dist: ', 115.72313383578795)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (28, [(x:1307, y:306), (x:1810, y:310)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 1307, 1794, '-', 1810, 1790)
# ('Angle:', 0.007952687111852163)
# ('x_A_j,y_A_j', 2344, 1794)
# ('x_B_j,y_B_j', 2483, 1790)
# ('x_C_j,y_C_j', 2344, 1794)
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 267.0074905316328)
# ('p_i_j:', -0.5308132173116638)
# ('parallel_dist: ', -267.0074905316328)
# ('x_M_j,y_M_j', 2077.0, 1792.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 123.5882745065799)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (6, [(x:2338, y:106), (x:2477, y:111)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 2338, 1994, '-', 2477, 1989)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.0023042388374287914)
# ('x_A_j,y_A_j', 2345, 1791)
# ('x_B_j,y_B_j', 2484, 1789)
# ('x_C_j,y_C_j', 2345, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 520.0009615375725)
# ('p_i_j:', -0.5990778584973219)
# ('parallel_dist: ', -520.0009615375725)
# ('x_M_j,y_M_j', 1825.0, 1790.0)
# ('delta_x_i:', 139)
# ('delta_y_i:', 5)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 115.32369501091097)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (8, [(x:3813, y:112), (x:4061, y:112)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 3813, 1988, '-', 4061, 1988)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2742, 1988)
# ('x_B_j,y_B_j', 2880, 1988)
# ('x_C_j,y_C_j', 3813, 1988)
# ('x_D_j,y_D_j', 2880, 1988)
# ('Overlap?', False)
# ('p_j:', 466.5)
# ('p_i_j:', -1.8810483870967742)
# ('parallel_dist: ', -466.5)
# ('x_M_j,y_M_j', 3346.5, 1988.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 248)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 30.06480257727385)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (9, [(x:4115, y:112), (x:4227, y:112)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 4115, 1988, '-', 4227, 1988)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2742, 1988)
# ('x_B_j,y_B_j', 2880, 1988)
# ('x_C_j,y_C_j', 4115, 1988)
# ('x_D_j,y_D_j', 2880, 1988)
# ('Overlap?', False)
# ('p_j:', 617.5)
# ('p_i_j:', -5.513392857142857)
# ('parallel_dist: ', -617.5)
# ('x_M_j,y_M_j', 3497.5, 1988.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 112)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 36.89325861513048)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (10, [(x:509, y:110), (x:1001, y:116)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 509, 1990, '-', 1001, 1984)
# ('Angle:', 0.012195594393295634)
# ('x_A_j,y_A_j', 2741, 1990)
# ('x_B_j,y_B_j', 2879, 1984)
# ('x_C_j,y_C_j', 2741, 1990)
# ('x_D_j,y_D_j', 1001, 1984)
# ('Overlap?', False)
# ('p_j:', 870.0051723984174)
# ('p_i_j:', -1.7681717186873562)
# ('parallel_dist: ', -870.0051723984174)
# ('x_M_j,y_M_j', 1871.0, 1987.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 492)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 35.9662165702559)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (11, [(x:2980, y:114), (x:3453, y:116)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 2980, 1986, '-', 3453, 1984)
# ('Angle:', 0.004228693063965611)
# ('x_A_j,y_A_j', 2743, 1986)
# ('x_B_j,y_B_j', 2881, 1984)
# ('x_C_j,y_C_j', 2980, 1986)
# ('x_D_j,y_D_j', 2881, 1984)
# ('Overlap?', False)
# ('p_j:', 49.51009997970111)
# ('p_i_j:', -0.10467158011779466)
# ('parallel_dist: ', -49.51009997970111)
# ('x_M_j,y_M_j', 2930.5, 1985.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 473)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 13.332824206366867)
# ... Angle ok!
# ... Perpendicular ok!
# ... Parallel ok!
# ('same group? ', True)
# ('before group idx: ', 1)
# ("before i's group: ", 1)
# ("before j's group: ", None)
# ... case 3
# ('after group idx: ', 1)
# ("after i's group: ", 1)
# ("after j's group: ", 1)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (12, [(x:1150, y:116), (x:1227, y:116)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 1150, 1984, '-', 1227, 1984)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2742, 1984)
# ('x_B_j,y_B_j', 2880, 1984)
# ('x_C_j,y_C_j', 2742, 1984)
# ('x_D_j,y_D_j', 1227, 1984)
# ('Overlap?', False)
# ('p_j:', 757.5)
# ('p_i_j:', -9.837662337662337)
# ('parallel_dist: ', -757.5)
# ('x_M_j,y_M_j', 1984.5, 1984.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 77)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 28.753377245500058)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (13, [(x:3494, y:130), (x:3732, y:102)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 3494, 1970, '-', 3732, 1998)
# ('Angle:', 0.1171299336069367)
# ('x_A_j,y_A_j', 2747, 1970)
# ('x_B_j,y_B_j', 2884, 1998)
# ('x_C_j,y_C_j', 3494, 1998)
# ('x_D_j,y_D_j', 2884, 1970)
# ('Overlap?', False)
# ('p_j:', 305.32114240582814)
# ('p_i_j:', -1.2740751138357107)
# ('parallel_dist: ', -305.32114240582814)
# ('x_M_j,y_M_j', 3189.0, 1984.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 238)
# ('delta_y_j:', 28)
# ('perpend_dist: ', 25.71599558627685)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (14, [(x:1360, y:108), (x:1707, y:128)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 1360, 1992, '-', 1707, 1972)
# ('Angle:', 0.05758038528448213)
# ('x_A_j,y_A_j', 2739, 1992)
# ('x_B_j,y_B_j', 2878, 1972)
# ('x_C_j,y_C_j', 2739, 1992)
# ('x_D_j,y_D_j', 1707, 1972)
# ('Overlap?', False)
# ('p_j:', 516.0968901282006)
# ('p_i_j:', -1.4848466291860638)
# ('parallel_dist: ', -516.0968901282006)
# ('x_M_j,y_M_j', 2223.0, 1982.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 347)
# ('delta_y_j:', 20)
# ('perpend_dist: ', 16.581239827024934)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (15, [(x:2228, y:156), (x:2235, y:114)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 2228, 1944, '-', 2235, 1986)
# ('Angle:', 1.406654402386406)
# ('x_A_j,y_A_j', 2631, 4362)
# ('x_B_j,y_B_j', 2740, 4362)
# ('x_C_j,y_C_j', 2631, 4362)
# ('x_D_j,y_D_j', 2235, 1986)
# ('Overlap?', False)
# ('p_j:', 1204.3869809990474)
# ('p_i_j:', -28.285714285714285)
# ('parallel_dist: ', -1204.3869809990474)
# ('x_M_j,y_M_j', 2433.0, 3174.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 7)
# ('delta_y_j:', 42)
# ('perpend_dist: ', 833.6142953764845)
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (17, [(x:2313, y:182), (x:2514, y:193)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 2313, 1918, '-', 2514, 1907)
# ('Angle:', 0.05468362903242875)
# ('x_A_j,y_A_j', 2744, 1918)
# ('x_B_j,y_B_j', 2883, 1907)
# ('x_C_j,y_C_j', 2744, 1918)
# ('x_D_j,y_D_j', 2514, 1907)
# ('Overlap?', False)
# ('p_j:', 115.1314466164653)
# ('p_i_j:', -0.5719374377959348)
# ('parallel_dist: ', -115.1314466164653)
# ('x_M_j,y_M_j', 2629.0, 1912.5)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 201)
# ('delta_y_j:', 11)
# ('perpend_dist: ', 49.96982729689787)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (18, [(x:2606, y:197), (x:2687, y:191)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 2606, 1903, '-', 2687, 1909)
# ('Angle:', 0.0739785775296521)
# ('x_A_j,y_A_j', 2745, 1903)
# ('x_B_j,y_B_j', 2882, 1909)
# ('x_C_j,y_C_j', 2745, 1909)
# ('x_D_j,y_D_j', 2687, 1903)
# ('Overlap?', False)
# ('p_j:', 29.154759474226502)
# ('p_i_j:', -0.3589518705257695)
# ('parallel_dist: ', -29.154759474226502)
# ('x_M_j,y_M_j', 2716.0, 1906.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 81)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 58.41118575429238)
# ... Angle ok!
# ... Perpendicular ok!
# ... Parallel ok!
# ('same group? ', True)
# ('before group idx: ', 1)
# ("before i's group: ", 1)
# ("before j's group: ", None)
# ... case 3
# ('after group idx: ', 1)
# ("after i's group: ", 1)
# ("after j's group: ", 1)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (19, [(x:2784, y:195), (x:3595, y:194)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 2784, 1905, '-', 3595, 1906)
# ('Angle:', 0.0012331110640265092)
# ('x_A_j,y_A_j', 2746, 1905)
# ('x_B_j,y_B_j', 2884, 1906)
# ('x_C_j,y_C_j', 2884, 1906)
# ('x_D_j,y_D_j', 2784, 1905)
# ('Overlap?', True)
# ('p_j:', 50.002499937503124)
# ('p_i_j:', 0.061655316800996694)
# ('parallel_dist: ', 50.002499937503124)
# ('x_M_j,y_M_j', 2834.0, 1905.5)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 811)
# ('delta_y_j:', 1)
# ('perpend_dist: ', 64.09402885864547)
# ... Angle ok!
# ... Perpendicular ok!
# ... Overlap & p_i_j ok!
# ('same group? ', True)
# ('before group idx: ', 1)
# ("before i's group: ", 1)
# ("before j's group: ", None)
# ... case 3
# ('after group idx: ', 1)
# ("after i's group: ", 1)
# ("after j's group: ", 1)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (20, [(x:3698, y:185), (x:4243, y:248)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 3698, 1915, '-', 4243, 1852)
# ('Angle:', 0.1150946288825137)
# ('x_A_j,y_A_j', 2750, 1915)
# ('x_B_j,y_B_j', 2893, 1852)
# ('x_C_j,y_C_j', 3698, 1915)
# ('x_D_j,y_D_j', 2893, 1852)
# ('Overlap?', False)
# ('p_j:', 403.7307270941859)
# ('p_i_j:', -0.7358899717434904)
# ('parallel_dist: ', -403.7307270941859)
# ('x_M_j,y_M_j', 3295.5, 1883.5)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 545)
# ('delta_y_j:', 63)
# ('perpend_dist: ', 100.21852089997753)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (21, [(x:2536, y:272), (x:2786, y:263)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 2536, 1828, '-', 2786, 1837)
# ('Angle:', 0.035990709997355326)
# ('x_A_j,y_A_j', 2749, 1828)
# ('x_B_j,y_B_j', 2887, 1837)
# ('x_C_j,y_C_j', 2786, 1837)
# ('x_D_j,y_D_j', 2749, 1828)
# ('Overlap?', True)
# ('p_j:', 19.03943276465977)
# ('p_i_j:', 0.07610842876556974)
# ('parallel_dist: ', 19.03943276465977)
# ('x_M_j,y_M_j', 2767.5, 1832.5)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 250)
# ('delta_y_j:', 9)
# ('perpend_dist: ', 111.70479794378933)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (22, [(x:3502, y:270), (x:3537, y:274)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 3502, 1830, '-', 3537, 1826)
# ('Angle:', 0.1139322302130506)
# ('x_A_j,y_A_j', 2752, 1830)
# ('x_B_j,y_B_j', 2889, 1826)
# ('x_C_j,y_C_j', 3502, 1830)
# ('x_D_j,y_D_j', 2889, 1826)
# ('Overlap?', False)
# ('p_j:', 306.5065252160221)
# ('p_i_j:', -8.700692776700057)
# ('parallel_dist: ', -306.5065252160221)
# ('x_M_j,y_M_j', 3195.5, 1828.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 35)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 134.17991483660222)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (23, [(x:3625, y:272), (x:3743, y:273)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 3625, 1828, '-', 3743, 1827)
# ('Angle:', 0.008477494903866015)
# ('x_A_j,y_A_j', 2749, 1828)
# ('x_B_j,y_B_j', 2887, 1827)
# ('x_C_j,y_C_j', 3625, 1828)
# ('x_D_j,y_D_j', 2887, 1827)
# ('Overlap?', False)
# ('p_j:', 369.00033875323203)
# ('p_i_j:', -3.1270092284069437)
# ('parallel_dist: ', -369.00033875323203)
# ('x_M_j,y_M_j', 3256.0, 1827.5)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 118)
# ('delta_y_j:', 1)
# ('perpend_dist: ', 137.26251805899005)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (24, [(x:3815, y:272), (x:3921, y:272)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 3815, 1828, '-', 3921, 1828)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 2749, 1828)
# ('x_B_j,y_B_j', 2887, 1828)
# ('x_C_j,y_C_j', 3815, 1828)
# ('x_D_j,y_D_j', 2887, 1828)
# ('Overlap?', False)
# ('p_j:', 464.0)
# ('p_i_j:', -4.377358490566038)
# ('parallel_dist: ', -464.0)
# ('x_M_j,y_M_j', 3351.0, 1828.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 106)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 141.21186790869962)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (25, [(x:2842, y:270), (x:3017, y:278)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 2842, 1830, '-', 3017, 1822)
# ('Angle:', 0.045693810649173015)
# ('x_A_j,y_A_j', 2749, 1830)
# ('x_B_j,y_B_j', 2888, 1822)
# ('x_C_j,y_C_j', 2888, 1830)
# ('x_D_j,y_D_j', 2842, 1822)
# ('Overlap?', False)
# ('p_j:', 23.345235059857504)
# ('p_i_j:', -0.1332621705018777)
# ('parallel_dist: ', -23.345235059857504)
# ('x_M_j,y_M_j', 2865.0, 1826.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 175)
# ('delta_y_j:', 8)
# ('perpend_dist: ', 120.6209828144123)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (26, [(x:3079, y:277), (x:3410, y:275)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 3079, 1823, '-', 3410, 1825)
# ('Angle:', 0.006043015797667825)
# ('x_A_j,y_A_j', 2750, 1823)
# ('x_B_j,y_B_j', 2887, 1825)
# ('x_C_j,y_C_j', 3079, 1825)
# ('x_D_j,y_D_j', 2887, 1823)
# ('Overlap?', False)
# ('p_j:', 96.00520819205592)
# ('p_i_j:', -0.2900406516512418)
# ('parallel_dist: ', -96.00520819205592)
# ('x_M_j,y_M_j', 2983.0, 1824.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 331)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 127.34392187155149)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (27, [(x:2230, y:303), (x:2440, y:253)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 2230, 1797, '-', 2440, 1847)
# ('Angle:', 0.23378981113187577)
# ('x_A_j,y_A_j', 2745, 1797)
# ('x_B_j,y_B_j', 2882, 1847)
# ('x_C_j,y_C_j', 2745, 1847)
# ('x_D_j,y_D_j', 2440, 1797)
# ('Overlap?', False)
# ('p_j:', 154.5355946052559)
# ('p_i_j:', -0.7158723182004352)
# ('parallel_dist: ', -154.5355946052559)
# ('x_M_j,y_M_j', 2592.5, 1822.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 210)
# ('delta_y_j:', 50)
# ('perpend_dist: ', 111.07169605948475)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (28, [(x:1307, y:306), (x:1810, y:310)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 1307, 1794, '-', 1810, 1790)
# ('Angle:', 0.007952805619641831)
# ('x_A_j,y_A_j', 2750, 1794)
# ('x_B_j,y_B_j', 2889, 1790)
# ('x_C_j,y_C_j', 2750, 1794)
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 470.00425529988553)
# ('p_i_j:', -0.934372554152551)
# ('parallel_dist: ', -470.00425529988553)
# ('x_M_j,y_M_j', 2280.0, 1792.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 117.74187662626522)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (7, [(x:2743, y:108), (x:2881, y:114)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 2743, 1992, '-', 2881, 1986)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.002304258735443705)
# ('x_A_j,y_A_j', 2751, 1791)
# ('x_B_j,y_B_j', 2889, 1789)
# ('x_C_j,y_C_j', 2751, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 723.0006915626014)
# ('p_i_j:', -0.8329478943898262)
# ('parallel_dist: ', -723.0006915626014)
# ('x_M_j,y_M_j', 2028.0, 1790.0)
# ('delta_x_i:', 138)
# ('delta_y_i:', 6)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 107.73283731249747)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (8, [(x:3813, y:112), (x:4061, y:112)])
# (9, [(x:4115, y:112), (x:4227, y:112)])
# ('i:', 3813, 1988, '-', 4061, 1988)
# ('j:', 4115, 1988, '-', 4227, 1988)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 3812, 1988)
# ('x_B_j,y_B_j', 4060, 1988)
# ('x_C_j,y_C_j', 4115, 1988)
# ('x_D_j,y_D_j', 4060, 1988)
# ('Overlap?', True)
# ('p_j:', 27.5)
# ('p_i_j:', 0.24553571428571427)
# ('parallel_dist: ', 27.5)
# ('x_M_j,y_M_j', 4087.5, 1988.0)
# ('delta_x_i:', 248)
# ('delta_y_i:', 0)
# ('delta_x_j:', 112)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 1.9170976472098817)
# ... Angle ok!
# ... Perpendicular ok!
# ... Overlap & p_i_j ok!
# ('same group? ', True)
# ('before group idx: ', 1)
# ("before i's group: ", None)
# ("before j's group: ", None)
# ... case 1
# ('after group idx: ', 2)
# ("after i's group: ", 2)
# ("after j's group: ", 2)
#
# ****************************************************************
# (8, [(x:3813, y:112), (x:4061, y:112)])
# (10, [(x:509, y:110), (x:1001, y:116)])
# ('i:', 3813, 1988, '-', 4061, 1988)
# ('j:', 509, 1990, '-', 1001, 1984)
# ('Angle:', 0.012194517448251816)
# ('x_A_j,y_A_j', 3812, 1990)
# ('x_B_j,y_B_j', 4060, 1984)
# ('x_C_j,y_C_j', 3812, 1990)
# ('x_D_j,y_D_j', 1001, 1984)
# ('Overlap?', False)
# ('p_j:', 1405.5032017039307)
# ('p_i_j:', -2.8565014216252744)
# ('parallel_dist: ', -1405.5032017039307)
# ('x_M_j,y_M_j', 2406.5, 1987.0)
# ('delta_x_i:', 248)
# ('delta_y_i:', 0)
# ('delta_x_j:', 492)
# ('delta_y_j:', 6)
# ('perpend_dist: ', 9.245602071516752)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (8, [(x:3813, y:112), (x:4061, y:112)])
# (11, [(x:2980, y:114), (x:3453, y:116)])
# ('i:', 3813, 1988, '-', 4061, 1988)
# ('j:', 2980, 1986, '-', 3453, 1984)
# ('Angle:', 0.004228304610879222)
# ('x_A_j,y_A_j', 3812, 1986)
# ('x_B_j,y_B_j', 4060, 1984)
# ('x_C_j,y_C_j', 3812, 1986)
# ('x_D_j,y_D_j', 3453, 1984)
# ('Overlap?', False)
# ('p_j:', 179.5027854937076)
# ('p_i_j:', -0.37949509697769246)
# ('parallel_dist: ', -179.5027854937076)
# ('x_M_j,y_M_j', 3632.5, 1985.0)
# ('delta_x_i:', 248)
# ('delta_y_i:', 0)
# ('delta_x_j:', 473)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 0.47141745423193815)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (8, [(x:3813, y:112), (x:4061, y:112)])
# (12, [(x:1150, y:116), (x:1227, y:116)])
# ('i:', 3813, 1988, '-', 4061, 1988)
# ('j:', 1150, 1984, '-', 1227, 1984)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 3812, 1984)
# ('x_B_j,y_B_j', 4060, 1984)
# ('x_C_j,y_C_j', 3812, 1984)
# ('x_D_j,y_D_j', 1227, 1984)
# ('Overlap?', False)
# ('p_j:', 1292.5)
# ('p_i_j:', -16.785714285714285)
# ('parallel_dist: ', -1292.5)
# ('x_M_j,y_M_j', 2519.5, 1984.0)
# ('delta_x_i:', 248)
# ...
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 846.5023626665197)
# ('p_i_j:', -1.6828540716003124)
# ('parallel_dist: ', -846.5023626665197)
# ('x_M_j,y_M_j', 2656.5, 1792.0)
# ('delta_x_i:', 35)
# ('delta_y_i:', 4)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 81.30476852322614)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (22, [(x:3502, y:270), (x:3537, y:274)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 3502, 1830, '-', 3537, 1826)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.0023044454921243834)
# ('x_A_j,y_A_j', 3505, 1791)
# ('x_B_j,y_B_j', 3540, 1789)
# ('x_C_j,y_C_j', 3505, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 1100.0004545453605)
# ('p_i_j:', -1.267278265614323)
# ('parallel_dist: ', -1100.0004545453605)
# ('x_M_j,y_M_j', 2405.0, 1790.0)
# ('delta_x_i:', 35)
# ('delta_y_i:', 4)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 111.25915692651999)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (23, [(x:3625, y:272), (x:3743, y:273)])
# (24, [(x:3815, y:272), (x:3921, y:272)])
# ('i:', 3625, 1828, '-', 3743, 1827)
# ('j:', 3815, 1828, '-', 3921, 1828)
# ('Angle:', 0.0)
# ('x_A_j,y_A_j', 3624, 1828)
# ('x_B_j,y_B_j', 3742, 1828)
# ('x_C_j,y_C_j', 3815, 1828)
# ('x_D_j,y_D_j', 3742, 1828)
# ('Overlap?', False)
# ('p_j:', 36.5)
# ('p_i_j:', -0.3443396226415094)
# ('parallel_dist: ', -36.5)
# ('x_M_j,y_M_j', 3778.5, 1828.0)
# ('delta_x_i:', 118)
# ('delta_y_i:', 1)
# ('delta_x_j:', 106)
# ('delta_y_j:', 0)
# ('perpend_dist: ', 2.60132129639466)
# ... Angle ok!
# ... Perpendicular ok!
# ... Parallel ok!
# ('same group? ', True)
# ('before group idx: ', 2)
# ("before i's group: ", 1)
# ("before j's group: ", None)
# ... case 3
# ('after group idx: ', 2)
# ("after i's group: ", 1)
# ("after j's group: ", 1)
#
# ****************************************************************
# (23, [(x:3625, y:272), (x:3743, y:273)])
# (25, [(x:2842, y:270), (x:3017, y:278)])
# ('i:', 3625, 1828, '-', 3743, 1827)
# ('j:', 2842, 1830, '-', 3017, 1822)
# ('Angle:', 0.04568469027872635)
# ('x_A_j,y_A_j', 3624, 1830)
# ('x_B_j,y_B_j', 3742, 1822)
# ('x_C_j,y_C_j', 3624, 1830)
# ('x_D_j,y_D_j', 3017, 1822)
# ('Overlap?', False)
# ('p_j:', 303.52635799877413)
# ('p_i_j:', -1.7326268580177449)
# ('parallel_dist: ', -303.52635799877413)
# ('x_M_j,y_M_j', 3320.5, 1826.0)
# ('delta_x_i:', 118)
# ('delta_y_i:', 1)
# ('delta_x_j:', 175)
# ('delta_y_j:', 8)
# ('perpend_dist: ', 4.160419402377127)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (23, [(x:3625, y:272), (x:3743, y:273)])
# (26, [(x:3079, y:277), (x:3410, y:275)])
# ('i:', 3625, 1828, '-', 3743, 1827)
# ('j:', 3079, 1823, '-', 3410, 1825)
# ('Angle:', 0.006042377235911138)
# ('x_A_j,y_A_j', 3624, 1823)
# ('x_B_j,y_B_j', 3742, 1825)
# ('x_C_j,y_C_j', 3624, 1825)
# ('x_D_j,y_D_j', 3410, 1823)
# ('Overlap?', False)
# ('p_j:', 107.00467279516349)
# ('p_i_j:', -0.3232710559322053)
# ('parallel_dist: ', -107.00467279516349)
# ('x_M_j,y_M_j', 3517.0, 1824.0)
# ('delta_x_i:', 118)
# ('delta_y_i:', 1)
# ('delta_x_j:', 331)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 0.16946718543287687)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (23, [(x:3625, y:272), (x:3743, y:273)])
# (27, [(x:2230, y:303), (x:2440, y:253)])
# ('i:', 3625, 1828, '-', 3743, 1827)
# ('j:', 2230, 1797, '-', 2440, 1847)
# ('Angle:', 0.23375227389148184)
# ('x_A_j,y_A_j', 3622, 1797)
# ('x_B_j,y_B_j', 3739, 1847)
# ('x_C_j,y_C_j', 3622, 1847)
# ('x_D_j,y_D_j', 2440, 1797)
# ('Overlap?', False)
# ('p_j:', 591.52852847517)
# ('p_i_j:', -2.740202993639692)
# ('parallel_dist: ', -591.52852847517)
# ('x_M_j,y_M_j', 3031.0, 1822.0)
# ('delta_x_i:', 118)
# ('delta_y_i:', 1)
# ('delta_x_j:', 210)
# ('delta_y_j:', 50)
# ('perpend_dist: ', 7.066781632550965)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (23, [(x:3625, y:272), (x:3743, y:273)])
# (28, [(x:1307, y:306), (x:1810, y:310)])
# ('i:', 3625, 1828, '-', 3743, 1827)
# ('j:', 1307, 1794, '-', 1810, 1790)
# ('Angle:', 0.00795225262870815)
# ('x_A_j,y_A_j', 3624, 1794)
# ('x_B_j,y_B_j', 3742, 1790)
# ('x_C_j,y_C_j', 3624, 1794)
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 907.0022050689844)
# ('p_i_j:', -1.8031282853632267)
# ('parallel_dist: ', -907.0022050689844)
# ('x_M_j,y_M_j', 2717.0, 1792.0)
# ('delta_x_i:', 118)
# ('delta_y_i:', 1)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 2.609794655666304)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (23, [(x:3625, y:272), (x:3743, y:273)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 3625, 1828, '-', 3743, 1827)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.0023041658835336568)
# ('x_A_j,y_A_j', 3625, 1791)
# ('x_B_j,y_B_j', 3743, 1789)
# ('x_C_j,y_C_j', 3625, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 1160.0004310344027)
# ('p_i_j:', -1.3364024789978168)
# ('parallel_dist: ', -1160.0004310344027)
# ('x_M_j,y_M_j', 2465.0, 1790.0)
# ('delta_x_i:', 118)
# ('delta_y_i:', 1)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 0.6609220231882198)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (24, [(x:3815, y:272), (x:3921, y:272)])
# (25, [(x:2842, y:270), (x:3017, y:278)])
# ('i:', 3815, 1828, '-', 3921, 1828)
# ('j:', 2842, 1830, '-', 3017, 1822)
# ('Angle:', 0.045682481074662766)
# ('x_A_j,y_A_j', 3814, 1830)
# ('x_B_j,y_B_j', 3920, 1822)
# ('x_C_j,y_C_j', 3814, 1830)
# ('x_D_j,y_D_j', 3017, 1822)
# ('Overlap?', False)
# ('p_j:', 398.52007477666666)
# ('p_i_j:', -2.27488179138657)
# ('parallel_dist: ', -398.52007477666666)
# ('x_M_j,y_M_j', 3415.5, 1826.0)
# ('delta_x_i:', 106)
# ('delta_y_i:', 0)
# ('delta_x_j:', 175)
# ('delta_y_j:', 8)
# ('perpend_dist: ', 5.372692047517356)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (24, [(x:3815, y:272), (x:3921, y:272)])
# (26, [(x:3079, y:277), (x:3410, y:275)])
# ('i:', 3815, 1828, '-', 3921, 1828)
# ('j:', 3079, 1823, '-', 3410, 1825)
# ('Angle:', 0.006042222540700726)
# ('x_A_j,y_A_j', 3814, 1823)
# ('x_B_j,y_B_j', 3920, 1825)
# ('x_C_j,y_C_j', 3814, 1825)
# ('x_D_j,y_D_j', 3410, 1823)
# ('Overlap?', False)
# ('p_j:', 202.00247523235947)
# ('p_i_j:', -0.6102682412224111)
# ('parallel_dist: ', -202.00247523235947)
# ('x_M_j,y_M_j', 3612.0, 1824.0)
# ('delta_x_i:', 106)
# ('delta_y_i:', 0)
# ('delta_x_j:', 331)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 1.0075499531583485)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (24, [(x:3815, y:272), (x:3921, y:272)])
# (27, [(x:2230, y:303), (x:2440, y:253)])
# ('i:', 3815, 1828, '-', 3921, 1828)
# ('j:', 2230, 1797, '-', 2440, 1847)
# ('Angle:', 0.23374318086890142)
# ('x_A_j,y_A_j', 3814, 1797)
# ('x_B_j,y_B_j', 3920, 1847)
# ('x_C_j,y_C_j', 3814, 1847)
# ('x_D_j,y_D_j', 2440, 1797)
# ('Overlap?', False)
# ('p_j:', 687.4547257819964)
# ('p_i_j:', -3.184572521693099)
# ('parallel_dist: ', -687.4547257819964)
# ('x_M_j,y_M_j', 3127.0, 1822.0)
# ('delta_x_i:', 106)
# ('delta_y_i:', 0)
# ('delta_x_j:', 210)
# ('delta_y_j:', 50)
# ('perpend_dist: ', 7.777196395189848)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (24, [(x:3815, y:272), (x:3921, y:272)])
# (28, [(x:1307, y:306), (x:1810, y:310)])
# ('i:', 3815, 1828, '-', 3921, 1828)
# ('j:', 1307, 1794, '-', 1810, 1790)
# ('Angle:', 0.00795211865750104)
# ('x_A_j,y_A_j', 3814, 1794)
# ('x_B_j,y_B_j', 3920, 1790)
# ('x_C_j,y_C_j', 3814, 1794)
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 1002.001996005996)
# ('p_i_j:', -1.9919886973719168)
# ('parallel_dist: ', -1002.001996005996)
# ('x_M_j,y_M_j', 2812.0, 1792.0)
# ('delta_x_i:', 106)
# ('delta_y_i:', 0)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 4.395096282155608)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (24, [(x:3815, y:272), (x:3921, y:272)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 3815, 1828, '-', 3921, 1828)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.002304143387804431)
# ('x_A_j,y_A_j', 3814, 1791)
# ('x_B_j,y_B_j', 3920, 1789)
# ('x_C_j,y_C_j', 3814, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 1254.5003985651022)
# ('p_i_j:', -1.4452731203307894)
# ('parallel_dist: ', -1254.5003985651022)
# ('x_M_j,y_M_j', 2559.5, 1790.0)
# ('delta_x_i:', 106)
# ('delta_y_i:', 0)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 1.4241854743292346)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (25, [(x:2842, y:270), (x:3017, y:278)])
# (26, [(x:3079, y:277), (x:3410, y:275)])
# ('i:', 2842, 1830, '-', 3017, 1822)
# ('j:', 3079, 1823, '-', 3410, 1825)
# ('Angle:', 0.006043056544014111)
# ('x_A_j,y_A_j', 2842, 1823)
# ('x_B_j,y_B_j', 3016, 1825)
# ('x_C_j,y_C_j', 3079, 1825)
# ('x_D_j,y_D_j', 3016, 1823)
# ('Overlap?', False)
# ('p_j:', 31.51586901863885)
# ('p_i_j:', -0.09521236774191558)
# ('parallel_dist: ', -31.51586901863885)
# ('x_M_j,y_M_j', 3047.5, 1824.0)
# ('delta_x_i:', 175)
# ('delta_y_i:', 8)
# ('delta_x_j:', 331)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 14.06268238540646)
# ... Angle ok!
# ... Perpendicular ok!
# ... Parallel ok!
# ('same group? ', True)
# ('before group idx: ', 2)
# ("before i's group: ", 1)
# ("before j's group: ", 1)
# ('after group idx: ', 2)
# ("after i's group: ", 1)
# ("after j's group: ", 1)
#
# ****************************************************************
# (25, [(x:2842, y:270), (x:3017, y:278)])
# (27, [(x:2230, y:303), (x:2440, y:253)])
# ('i:', 2842, 1830, '-', 3017, 1822)
# ('j:', 2230, 1797, '-', 2440, 1847)
# ('Angle:', 0.23379220649916993)
# ('x_A_j,y_A_j', 2836, 1797)
# ('x_B_j,y_B_j', 3009, 1847)
# ('x_C_j,y_C_j', 2836, 1847)
# ('x_D_j,y_D_j', 2440, 1797)
# ('Overlap?', False)
# ('p_j:', 199.5720421301541)
# ('p_i_j:', -0.9244996326745893)
# ('parallel_dist: ', -199.5720421301541)
# ('x_M_j,y_M_j', 2638.0, 1822.0)
# ('delta_x_i:', 175)
# ('delta_y_i:', 8)
# ('delta_x_j:', 210)
# ('delta_y_j:', 50)
# ('perpend_dist: ', 3.585230005522747)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (25, [(x:2842, y:270), (x:3017, y:278)])
# (28, [(x:1307, y:306), (x:1810, y:310)])
# ('i:', 2842, 1830, '-', 3017, 1822)
# ('j:', 1307, 1794, '-', 1810, 1790)
# ('Angle:', 0.00795284090439481)
# ('x_A_j,y_A_j', 2842, 1794)
# ('x_B_j,y_B_j', 3017, 1790)
# ('x_C_j,y_C_j', 2842, 1794)
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 516.0038759544351)
# ('p_i_j:', -1.0258202007565507)
# ('parallel_dist: ', -516.0038759544351)
# ('x_M_j,y_M_j', 2326.0, 1792.0)
# ('delta_x_i:', 175)
# ('delta_y_i:', 8)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 4.137457376041651)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (25, [(x:2842, y:270), (x:3017, y:278)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 2842, 1830, '-', 3017, 1822)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.0023042646598714065)
# ('x_A_j,y_A_j', 2843, 1791)
# ('x_B_j,y_B_j', 3018, 1789)
# ('x_C_j,y_C_j', 2843, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 769.0006501947837)
# ('p_i_j:', -0.8859430977580068)
# ('parallel_dist: ', -769.0006501947837)
# ('x_M_j,y_M_j', 2074.0, 1790.0)
# ('delta_x_i:', 175)
# ('delta_y_i:', 8)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 6.150963327010588)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (26, [(x:3079, y:277), (x:3410, y:275)])
# (27, [(x:2230, y:303), (x:2440, y:253)])
# ('i:', 3079, 1823, '-', 3410, 1825)
# ('j:', 2230, 1797, '-', 2440, 1847)
# ('Angle:', 0.23374966411682865)
# ('x_A_j,y_A_j', 3077, 1797)
# ('x_B_j,y_B_j', 3408, 1847)
# ('x_C_j,y_C_j', 3077, 1847)
# ('x_D_j,y_D_j', 2440, 1797)
# ('Overlap?', False)
# ('p_j:', 319.4796550642936)
# ('p_i_j:', -1.4799609233908673)
# ('parallel_dist: ', -319.4796550642936)
# ('x_M_j,y_M_j', 2758.5, 1822.0)
# ('delta_x_i:', 331)
# ('delta_y_i:', 2)
# ('delta_x_j:', 210)
# ('delta_y_j:', 50)
# ('perpend_dist: ', 2.0326445531318154)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (26, [(x:3079, y:277), (x:3410, y:275)])
# (28, [(x:1307, y:306), (x:1810, y:310)])
# ('i:', 3079, 1823, '-', 3410, 1825)
# ('j:', 1307, 1794, '-', 1810, 1790)
# ('Angle:', 0.007952214178419818)
# ('x_A_j,y_A_j', 3079, 1794)
# ('x_B_j,y_B_j', 3410, 1790)
# ('x_C_j,y_C_j', 3079, 1794)
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 634.503152080429)
# ('p_i_j:', -1.2613977940454177)
# ('parallel_dist: ', -634.503152080429)
# ('x_M_j,y_M_j', 2444.5, 1792.0)
# ('delta_x_i:', 331)
# ('delta_y_i:', 2)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 11.331813539028605)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (26, [(x:3079, y:277), (x:3410, y:275)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 3079, 1823, '-', 3410, 1825)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.002304159427199307)
# ('x_A_j,y_A_j', 3079, 1791)
# ('x_B_j,y_B_j', 3410, 1789)
# ('x_C_j,y_C_j', 3079, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 887.0005636976788)
# ('p_i_j:', -1.0218873376977937)
# ('parallel_dist: ', -887.0005636976788)
# ('x_M_j,y_M_j', 2192.0, 1790.0)
# ('delta_x_i:', 331)
# ('delta_y_i:', 2)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 10.371842595925456)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (27, [(x:2230, y:303), (x:2440, y:253)])
# (28, [(x:1307, y:306), (x:1810, y:310)])
# ('i:', 2230, 1797, '-', 2440, 1847)
# ('j:', 1307, 1794, '-', 1810, 1790)
# ('Angle:', 0.007955815554558975)
# ('x_A_j,y_A_j', 2228, 1794)
# ('x_B_j,y_B_j', 2452, 1790)
# ('x_C_j,y_C_j', 2228, 1794)
# ('x_D_j,y_D_j', 1810, 1790)
# ('Overlap?', False)
# ('p_j:', 209.0095691589263)
# ('p_i_j:', -0.4155128443523217)
# ('parallel_dist: ', -209.0095691589263)
# ('x_M_j,y_M_j', 2019.0, 1792.0)
# ('delta_x_i:', 210)
# ('delta_y_i:', 50)
# ('delta_x_j:', 503)
# ('delta_y_j:', 4)
# ('perpend_dist: ', 45.06360386014646)
# ... Angle ok!
# ... Perpendicular ok!
# ('same group? ', False)
#
# ****************************************************************
# (27, [(x:2230, y:303), (x:2440, y:253)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 2230, 1797, '-', 2440, 1847)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.00230476403408263)
# ('x_A_j,y_A_j', 2230, 1791)
# ('x_B_j,y_B_j', 2453, 1789)
# ('x_C_j,y_C_j', 2230, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 462.5010810798176)
# ('p_i_j:', -0.5328339324348988)
# ('parallel_dist: ', -462.5010810798176)
# ('x_M_j,y_M_j', 1767.5, 1790.0)
# ('delta_x_i:', 210)
# ('delta_y_i:', 50)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 102.47489311629573)
# ... Angle ok!
# ('same group? ', False)
#
# ****************************************************************
# (28, [(x:1307, y:306), (x:1810, y:310)])
# (29, [(x:437, y:309), (x:1305, y:311)])
# ('i:', 1307, 1794, '-', 1810, 1790)
# ('j:', 437, 1791, '-', 1305, 1789)
# ('Angle:', 0.0023041644971646103)
# ('x_A_j,y_A_j', 1306, 1791)
# ('x_B_j,y_B_j', 1809, 1789)
# ('x_C_j,y_C_j', 1306, 1791)
# ('x_D_j,y_D_j', 1305, 1789)
# ('Overlap?', False)
# ('p_j:', 1.118033988749895)
# ('p_i_j:', -0.0012880541715288934)
# ('parallel_dist: ', -1.118033988749895)
# ('x_M_j,y_M_j', 1305.5, 1790.0)
# ('delta_x_i:', 503)
# ('delta_y_i:', 4)
# ('delta_x_j:', 868)
# ('delta_y_j:', 2)
# ('perpend_dist: ', 2.47773214123911)
# ... Angle ok!
# ... Perpendicular ok!
# ... Parallel ok!
# ('same group? ', True)
# ('before group idx: ', 2)
# ("before i's group: ", None)
# ("before j's group: ", None)
# ... case 1
# ('after group idx: ', 3)
# ("after i's group: ", 3)
# ("after j's group: ", 3)
# Done!

# %%
import cv2
image = page.image.copy()
for my_line in my_lines:
    #print(my_line.start.x)
#    print my_line.group
    if my_line.group == None:
        blue  = 0
        green = 0 
        red   = 0
    else:
        blue = (my_line.group*100)%255
        green = (my_line.group*200)%255
        red = (my_line.group*300)%255
        
    #print(blue,green,red)
    cv2.line(image, (my_line.start.x,my_line.start.y), (my_line.end.x,my_line.end.y), (blue,green,red),30)
    
cv2.imwrite(outputPath, image) 
maxDimension = Dimension(800, 800)
displayDimension = Dimension(image.shape[1], image.shape[0])
displayDimension.fitInside(maxDimension)
image = cv2.resize(image, tuple(displayDimension))
cv2.namedWindow('title', cv2.CV_WINDOW_AUTOSIZE)
cv2.imshow('grouped', image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
for my_line in my_lines:
    my_line.group = None
    #print(my_line.group)

# %%
#########################
# TESTING FINDING PEAKS #
#########################

from scipy.signal import find_peaks_cwt
cb = [3, 2, 5,3,5, 7, 8, 8, 8, 9, 16, 15, 14, 14, 15, 16, 17, 17, 26 ,34, 24, 34, 36]
indexes = find_peaks_cwt(cb, numpy.arange(1, 40))

# %%
indexes[0]

# %%
group_idx = -1
sameGroup = False
threshold_angle = 1.0
threshold_perpendist = 5.0
threshold_overlap    = 1.0
threshold_paralldist = 5.0
# 1. angle check
if theta_i_j < threshold_angle:
# 2. perpend_dist check
    if d_e_i_j < threshold_perpendist:
# 3.a. overlap check
# 3.b. parallel_dist check
        if (overlap and p_i_j < threshold_overlap) or d_i_j_a < threshold_paralldist:
            # Group!
            sameGroup = True
if sameGroup:
    if (my_lines[0].group == None) and (my_lines[5].group == None):
        # Assign to a new block
        group_idx = group_idx + 1
        my_lines[0].group = group_idx
        my_lines[5].group = group_idx
    elif (my_lines[0].group == None):
        # Unassigned text-line is assigned to the block of the other
        my_lines[0].group = my_lines[5].group
    elif (my_lines[5].group == None):
        # Unassigned text-line is assigned to the block of the other
        my_lines[5].group = my_lines[0].group
    #else:
        # Block merge

# %%
print(my_lines[0].group)
print(my_lines[5].group)
print(sameGroup)

# %%
x_middle_candidates

# %%
0.5*20/2

# %%
#dir(words)
for word in words:
    #dir(word)
    #word.angles
    points = []
    multiplier = 1
    for character in word.characters:
        #print "(",character.x,", ",character.y,")"
        #print "nn: ", character.nearestNeighbors
        points.append([character.x, character.y])
    points.sort(key=lambda x: x[0])
    #print(points)
    w = max(points,key=lambda x: x[0])[0]-min(points,key=lambda x: x[0])[0]
    #print(w)
    h = max(points,key=lambda x: x[1])[1]-min(points,key=lambda x: x[1])[1]
    #print(h)
    dx, dy, x0, y0 = cv2.fitLine(numpy.array(points), cv2.cv.CV_DIST_L2, 0, 0.01, 0.01)
    start = (int(x0 - dx*w/2), int(y0 - dy*w/2))
    #start = (int(x0 - dx*w), int(y0 - dy*w))
    end = (int(x0 + dx*w/2), int(y0 + dy*w/2))
    #end = (int(x0 + dx*w), int(y0 + dy*w))
    #angle = self.calculateAngle(self.start, self.end)
    cv2.line(greyscaleImage, start, end, (0,0,255),5)

# %%
boundingBox = [800,800]
maxDimension = Dimension(boundingBox[0], boundingBox[1])
displayDimension = Dimension(greyscaleImage.shape[1], greyscaleImage.shape[0])
displayDimension.fitInside(maxDimension)
greyscaleImage = cv2.resize(greyscaleImage, tuple(displayDimension))
cv2.namedWindow('fit line', cv2.CV_WINDOW_AUTOSIZE)
cv2.imshow('fit line', greyscaleImage)
cv2.waitKey()

# %%
#save
cv2.imwrite(outputPath, greyscaleImage)

# %%
print "Total ", len(words), " words are found."
for idx, word in enumerate(words):
    print "[",idx,"] word:"
    for idx_char, character in enumerate(word.characters):
        print "**[", idx_char, "] char info.. ", "(",character.x,",",character.y,")"

# %%
#dir(word)
#word.angles
points = []
multiplier = 1
for character in word.characters:
    #print "(",character.x,", ",character.y,")"
    points.append([character.x, character.y])
points.sort(key=lambda x: x[0])
print(points)
w = max(points,key=lambda x: x[0])[0]-min(points,key=lambda x: x[0])[0]
print(w)
h = max(points,key=lambda x: x[1])[1]-min(points,key=lambda x: x[1])[1]
print(h)
dx, dy, x0, y0 = cv2.fitLine(numpy.array(points), cv2.cv.CV_DIST_L2, 0, 0.01, 0.01)
#start = (int(x0 - dx*multiplier), int(y0 - dy*multiplier))
start = (int(x0 - dx*w), int(y0 - dy*w))
#end = (int(x0 + dx*multiplier), int(y0 + dy*multiplier))
end = (int(x0 + dx*w), int(y0 + dy*w))
#angle = self.calculateAngle(self.start, self.end)
cv2.line(greyscaleImage, start, end, (0,0,255),5)

        
print "dx: ",dx, ", dy: ",dy, ", x0: ",x0,", y0: ",y0
print "start: ",start,", end: ",end#,", angle: ", angle



cv2.namedWindow('fit line', cv2.CV_WINDOW_AUTOSIZE)
cv2.imshow('fit line', greyscaleImage)
cv2.waitKey()

# %%
char = word.characters.pop()

# %%
print "(", char.x, ", ", char.y, ")"

# %%
dir(char)

# %%
# DOCSTRUM PLOTING TEST
import numpy as np
import matplotlib.pyplot as plt
# radtodeg(0.5880026035475674) = 33.6901
# radtodeg(0.21687361566640817) = 12.4259
#theta = [np.pi+(0.5880026035475674), np.pi+0.21687361566640817, 2*np.pi-(0.5880026035475674), 2*np.pi-(0.21687361566640817)] 
theta = [1/2*np.pi+(0.5880026035475674), 1/2*np.pi+(0.21687361566640817),3/2*np.pi+(0.5880026035475674), 3/2*np.pi+(0.21687361566640817)] 
r = [57.688820407423826, 60.41522986797286, 57.688820407423826, 60.41522986797286]
fig = plt.figure()
ax = plt.subplot(111,polar=True)
ax.scatter(theta,r)
plt.savefig(os.path.join(os.path.abspath("./docstrums"),'foo'))
plt.show()
